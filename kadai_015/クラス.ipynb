# %%
class human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
       print(f"名前は{self.name}、{self.age}歳です。")

taro = human("侍太郎", 36)
hanako = human("侍花子", 30)

taro.printinfo()
hanako.printinfo()
